# %% [markdown]
# # TP 1 - Notebook Test
# Notebook de prueba para el Trabajo Práctico 1

# %%
import sys
import numpy as np
import pandas as pd
import sklearn

print("Versión del Intérprete Python:", sys.version)
print("Versión de NumPy:", np.__version__)
print("Versión de Pandas:", pd.__version__)
print("Versión de Scikit-learn:", sklearn.__version__)
print("¡El Workspace en Antigravity IDE y el entorno virtual se ejecutan correctamente!")
# Out:
# Versión del Intérprete Python: 3.12.13 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:47) [MSC v.1942 64 bit (AMD64)]
# Versión de NumPy: 2.5.2
# Versión de Pandas: 3.0.5
# Versión de Scikit-learn: 1.9.0
# ¡El Workspace en Antigravity IDE y el entorno virtual se ejecutan correctamente!

# %% [markdown]
# Prueba de impresión

# %%
print("This is a test and therefore no further comments will be added :)")
# Out:
# This is a test and therefore no further comments will be added :)

# %% [markdown]
# 2da Prueba de Impresión

# %%
print("I realised I was unknowingly using my other GitHub account to upload the repository so I just logged in again.")
# Out:
# I realised I was unknowingly using my other GitHub account to upload the repository so I just logged in again.

# %% [markdown]
# 3ra Prueba de Impresión

# %%
print("I finally figured out what was wrong and now I can upload from this account :)")
# Out:
# I finally figured out what was wrong and now I can upload from this account :)
